# %%
#Import libraries and give nickname
import pandas as pd
import numpy as np

# %%
#Tell pandas to show all columns when table is printed
pd.set_option("display.max_columns", None)

# %%
#A helper path so we do not have to continue to retype folder
RAW = "../data/raw"

# %%
#Read each csv into pandas dataframe
customers = pd.read_csv(RAW + "olist_customers_dataset.csv")
orders = pd.read_csv(RAW + "olist_orders_dataset.csv")
order_items = pd.read_csv(RAW + "olist_order_items_dataset.csv")
payments = pd.read_csv(RAW + "olist_order_payments_dataset.csv")
reviews = pd.read_csv(RAW + "olist_order_reviews_dataset.csv")
products = pd.read_csv(RAW + "olist_products_dataset.csv")
sellers = pd.read_csv(RAW + "olist_sellers_dataset.csv")
geolocation = pd.read_csv(RAW + "olist_geolocation_dataset.csv")
translation = pd.read_csv(RAW + "olist_product_category_name_translation_dataset.csv")

print("all files loaded successfully")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 2
#       1 #Read each csv into pandas dataframe
# ----> 2 customers = pd.read_csv(RAW + "olist_customers_dataset.csv")
#       3 orders = pd.read_csv(RAW + "olist_orders_dataset.csv")
#       4 order_items = pd.read_csv(RAW + "olist_order_items_dataset.csv")
#
# ...
